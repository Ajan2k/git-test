# %%
import pandas as pd

df =pd.read_excel("google_maps_results.xlsx")
df
# Out:
#                                                  name  \
# 0   CLARISCO - Blockchain, AI & IoT Software Devel...
# 1   Tecneural Software Solutions—Blockchain, AI, B...
# 2                         Abservetech Private Limited
# 3               Innervex Technologies Private Limited
# 4                     AI BEING SOFTWARE SOLUTIONS LLP
# 5                Elysium Technologies Private Limited
# 6   Alpharive Tech Pvt Ltd - Software Development ...
# 7   AstraByte Technologies | IT Training in Madura...
# 8                     Boostimize Technologies Pvt Ltd
# 9   ARM InfoTech - AI & Blockchain Development Com...
# 10  IUNOWARE PRIVATE LIMITED | Software Training c...
# 11  Bhive Technologies | Mobile App Development in...
# 12                        Maticz Technologies Pvt Ltd
# 13  ACTE Technologies - Best Data Analytics, Fulls...
# 14                                  Greens Technology
# 15  ACTE Technologies - Training & Placement in Po...
# ...
